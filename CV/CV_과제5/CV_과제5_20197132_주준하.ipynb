# %% [markdown]
# # 수강생분의 이름, 학번을 반영해주세요.

# %%
id = '20197132'
name = '주준하'
print(id, name)
# Out:
# 20197132 주준하

# %% [markdown]
# 코랩 메뉴 -> 수정 -> 노트 설정 -> 하드웨어 가속기 GPU 권장(행렬 연산이 많기 때문)

# %% [markdown]
# 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# 폴더 경로 설정

# %%
workspace_path = '/gdrive/My Drive/Colab Notebooks/CV_과제5'

# %% [markdown]
# 필요 패키지 로드

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 결과 재현을 위한 설정

# %%
seed = 1
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# 합성곱 신경망(CNN) 정의

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 3x32x32 -> 10x32x32
            nn.BatchNorm2d(10),  # 배치 정규화
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 10x32x32 -> 20x32x32
            nn.BatchNorm2d(20),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # 20x32x32 -> 20x16x16 (특징 압축)
            nn.Conv2d(in_channels=20, out_channels=40, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 20x16x16 -> 40x16x16
            nn.BatchNorm2d(40),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=40, out_channels=80, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 40x8x8 -> 80x8x8
            nn.BatchNorm2d(80),
            nn.AdaptiveAvgPool2d(1)  # 80x8x8 -> 80x1x1 (채널 별 평균값 계산)
        )
        self.fc = nn.Linear(80, 10)  # 출력값의 차원은 판별할 클래스 수인 10으로 설정 (CIFAR-10 10종 판별 문제)

    def forward(self, x):
        x = x.float()
        x = x.view(-1, 3, 32, 32)  # view 함수로 tensor 형태 변경: [batch크기, 3, 32, 32]
        x = self.main(x)  # CNN 모델 feed-forward
        x = x.view(-1, 80)  # view 함수로 형태 변경: [batch크기, 80]
        x = self.fc(x)  # 마지막 레이어에는 활성화 함수 사용하지 않음
        return x

print("init model done")
# Out:
# init model done

# %% [markdown]
# 모델 학습을 위한 하이퍼파라미터 셋팅

# %%
batch_size = 64  # 학습 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (학습 과정을 제외하므로 더 큰 배치 사용 가능)
max_epochs = 10  # 학습 데이터셋 총 훈련 횟수
lr = 0.01  # 학습률
momentum = 0.5  # SGD에 사용할 모멘텀 설정 (파라미터 업데이트 시 관성 효과 사용)
log_interval = 200  # interval 때마다 로그 남김

use_cuda = torch.cuda.is_available()  # GPU cuda 사용 여부 확인

device = torch.device("cuda" if use_cuda else "cpu")  # GPU cuda 사용하거나 없다면 CPU 사용

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}  # num_workers: data loading할 프로세스 수, pin_memory: 고정된 메모리 영역 사용

print("set vars and device done")
# Out:
# set vars and device done

# %% [markdown]
# 데이터 로더 정의 (학습용, 테스트용 따로 정의)

# %%
transform = transforms.Compose([
                 transforms.ToTensor(),  # numpy array -> tensor 변환
                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])  # 입력값 정규화 (일반적으로는 학습 데이터셋의 평균, 표준편차 사용)

# CIFAR-10 link: https://www.cs.toronto.edu/~kriz/cifar.html
# 학습용 데이터 로더 (CIFAR-10 학습 데이터셋 사용)
train_loader = torch.utils.data.DataLoader(
  datasets.CIFAR10(os.path.join(workspace_path, 'data'), train=True, download=True, 
                   transform=transform), 
    batch_size = batch_size, shuffle=True, drop_last=True, **kwargs)  # drop_last: 마지막 미니배치 크기가 batch_size 이하면 drop 

# 테스트용 데이터 로더 (CIFAR-10 테스트 데이터셋 사용)
test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(os.path.join(workspace_path, 'data'), train=False, download=True,
                         transform=transform), 
    batch_size=test_batch_size, shuffle=False, **kwargs)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /gdrive/My Drive/Colab Notebooks/data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /gdrive/My Drive/Colab Notebooks/data/cifar-10-python.tar.gz to /gdrive/My Drive/Colab Notebooks/data
# Files already downloaded and verified

# %% [markdown]
# 모델, 최적화 알고리즘, 손실 함수 정의

# %%
model = Net().to(device)  # 모델 정의
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)  # 최적화 알고리즘 정의 (SGD 사용)
criterion = nn.CrossEntropyLoss()  # 손실 함수 정의 (CrossEntropy 사용)

# %% [markdown]
# AverageMeter 정의

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# 학습, 테스트용 함수 정의

# %%
def train(log_interval, model, device, train_loader, optimizer, epoch):
    model.train()  # 모델 학습 모드 설정
    summary_loss = AverageMeter()  # 학습 손실값 기록 초기화
    summary_acc = AverageMeter() # 학습 정확도 기록 초기화
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)  # 현재 미니 배치의 데이터, 정답 불러옴
        optimizer.zero_grad()  # gradient 0으로 초기화
        output = model(data)  # 모델에 입력값 feed-forward
        loss = criterion(output, target)  # 예측값(클래스 별 score)과 정답간의 손실값 계산
        loss.backward()  # 손실값 역전파 (각 계층에서 gradient 계산, pytorch는 autograd로 gradient 자동 계산)
        optimizer.step()  # 모델의 파라미터 업데이트 (gradient 이용하여 파라미터 업데이트)
        summary_loss.update(loss.detach().item())  # 손실값 기록
        pred = output.argmax(dim=1, keepdim=True)  # 예측값 중에서 최고 score를 달성한 클래스 선발
        correct = pred.eq(target.view_as(pred)).sum().item()  # 정답과 예측 클래스가 일치한 개수
        summary_acc.update(correct / data.size(0))  # 정확도 기록
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tAverage loss: {:.6f}, Accuracy: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), summary_loss.avg, summary_acc.avg))
            
    return summary_loss.avg, summary_acc.avg

def test(log_interval, model, device, test_loader):
    model.eval()  # 모델 검증 모드 설정 (inference mode)
    summary_loss = AverageMeter()  # 테스트 손실값 기록 초기화
    summary_acc = AverageMeter() # 테스트 정확도 기록 초기화
    with torch.no_grad():  # 검증 모드이므로 gradient 계산안함
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  # 현재 미니 배치의 데이터, 정답 불러옴
            output = model(data)  # 모델에 입력값 feed-forward
            loss = criterion(output, target)  # 예측값(클래스 별 score)과 정답간의 손실값 계산
            summary_loss.update(loss.detach().item())  # 손실값 기록
            pred = output.argmax(dim=1, keepdim=True)  # 예측값 중에서 최고 score를 달성한 클래스 선발
            correct = pred.eq(target.view_as(pred)).sum().item()  # 정답과 예측 클래스가 일치한 개수
            summary_acc.update(correct / data.size(0))  # 정확도 기록

    print('\nTest set: Average loss: {:.4f}, Accuracy: {:.6f}\n'.format
          (summary_loss.avg, summary_acc.avg))  # 정답을 맞춘 개수 / 테스트셋 샘플 수 -> Accuracy

    return summary_loss.avg, summary_acc.avg

# %% [markdown]
# 학습, 테스트, 모델 저장 수행

# %%
best_acc = 0
best_epoch = 0
for epoch in range(1, max_epochs+1):
    train_loss, train_acc = train(log_interval, model, device, train_loader, optimizer, epoch)
    test_loss, test_acc = test(log_interval, model, device, test_loader)

    # 테스트에서 best accuracy 달성하면 모델 저장
    if test_acc > best_acc:
        best_acc = test_acc
        best_epoch = epoch
        torch.save(model, os.path.join(workspace_path, f'cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt'))
        print(f'# save model: cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt\n')

print(f'\n\n# Best accuracy model({best_acc * 100:.2f}%): cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt\n')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Average loss: 2.298636, Accuracy: 0.109375
# Train Epoch: 1 [12800/50000 (26%)]	Average loss: 1.852039, Accuracy: 0.322217
# Train Epoch: 1 [25600/50000 (51%)]	Average loss: 1.741262, Accuracy: 0.367869
# Train Epoch: 1 [38400/50000 (77%)]	Average loss: 1.671902, Accuracy: 0.397047
#
# Test set: Average loss: 1.4414, Accuracy: 0.489600
#
# # save model: cifar10_cnn_model_best_acc_1-epoch.pt
#
# Train Epoch: 2 [0/50000 (0%)]	Average loss: 1.511683, Accuracy: 0.546875
# Train Epoch: 2 [12800/50000 (26%)]	Average loss: 1.407018, Accuracy: 0.497823
# Train Epoch: 2 [25600/50000 (51%)]	Average loss: 1.386691, Accuracy: 0.507053
# Train Epoch: 2 [38400/50000 (77%)]	Average loss: 1.376745, Accuracy: 0.510087
#
# Test set: Average loss: 1.4488, Accuracy: 0.454000
#
# Train Epoch: 3 [0/50000 (0%)]	Average loss: 1.257560, Accuracy: 0.515625
# Train Epoch: 3 [12800/50000 (26%)]	Average loss: 1.262589, Accuracy: 0.550995
# Train Epoch: 3 [25600/50000 (51%)]	Average loss: 1.256609, Accuracy: 0.552720
# Train Epoch: 3 [38400/50000 (77%)]	Average loss: 1.253781, Accuracy: 0.554415
#
# Test set: Average loss: 1.2942, Accuracy: 0.527900
#
# # save model: cifar10_cnn_model_best_acc_3-epoch.pt
#
# Train Epoch: 4 [0/50000 (0%)]	Average loss: 1.201814, Accuracy: 0.593750
# Train Epoch: 4 [12800/50000 (26%)]	Average loss: 1.176248, Accuracy: 0.585354
# Train Epoch: 4 [25600/50000 (51%)]	Average loss: 1.169821, Accuracy: 0.586347
# Train Epoch: 4 [38400/50000 (77%)]	Average loss: 1.162834, Accuracy: 0.590214
#
# Test set: Average loss: 1.2967, Accuracy: 0.539600
#
# # save model: cifar10_cnn_model_best_acc_4-epoch.pt
#
# Train Epoch: 5 [0/50000 (0%)]	Average loss: 1.279975, Accuracy: 0.578125
# Train Epoch: 5 [12800/50000 (26%)]	Average loss: 1.102487, Accuracy: 0.612873
# Train Epoch: 5 [25600/50000 (51%)]	Average loss: 1.101532, Accuracy: 0.614090
# Train Epoch: 5 [38400/50000 (77%)]	Average loss: 1.099434, Accuracy: 0.613561
#
# Test set: Average loss: 1.2248, Accuracy: 0.573300
#
# # save model: cifar10_cnn_model_best_acc_5-epoch.pt
#
# Train Epoch: 6 [0/50000 (0%)]	Average loss: 1.176812, Accuracy: 0.671875
# Train Epoch: 6 [12800/50000 (26%)]	Average loss: 1.047444, Accuracy: 0.631608
# Train Epoch: 6 [25600/50000 (51%)]	Average loss: 1.046975, Accuracy: 0.632403
# Train Epoch: 6 [38400/50000 (77%)]	Average loss: 1.045210, Accuracy: 0.631084
#
# Test set: Average loss: 1.0792, Accuracy: 0.616200
#
# # save model: cifar10_cnn_model_best_acc_6-epoch.pt
#
# Train Epoch: 7 [0/50000 (0%)]	Average loss: 0.833904, Accuracy: 0.671875
# Train Epoch: 7 [12800/50000 (26%)]	Average loss: 0.997728, Accuracy: 0.651586
# Train Epoch: 7 [25600/50000 (51%)]	Average loss: 1.006750, Accuracy: 0.646470
# Train Epoch: 7 [38400/50000 (77%)]	Average loss: 1.010256, Accuracy: 0.644395
#
# Test set: Average loss: 1.0930, Accuracy: 0.604300
#
# Train Epoch: 8 [0/50000 (0%)]	Average loss: 0.930360, Accuracy: 0.625000
# Train Epoch: 8 [12800/50000 (26%)]	Average loss: 0.988501, Accuracy: 0.652285
# Train Epoch: 8 [25600/50000 (51%)]	Average loss: 0.985703, Accuracy: 0.654263
# Train Epoch: 8 [38400/50000 (77%)]	Average loss: 0.985710, Accuracy: 0.655080
#
# Test set: Average loss: 1.0297, Accuracy: 0.628600
#
# # save model: cifar10_cnn_model_best_acc_8-epoch.pt
#
# Train Epoch: 9 [0/50000 (0%)]	Average loss: 0.870239, Accuracy: 0.718750
# Train Epoch: 9 [12800/50000 (26%)]	Average loss: 0.940634, Accuracy: 0.666978
# Train Epoch: 9 [25600/50000 (51%)]	Average loss: 0.953681, Accuracy: 0.660848
# Train Epoch: 9 [38400/50000 (77%)]	Average loss: 0.955059, Accuracy: 0.660852
#
# Test set: Average loss: 1.2851, Accuracy: 0.564100
#
# Train Epoch: 10 [0/50000 (0%)]	Average loss: 1.024620, Accuracy: 0.734375
# Train Epoch: 10 [12800/50000 (26%)]	Average loss: 0.927340, Accuracy: 0.677861
# Train Epoch: 10 [25600/50000 (51%)]	Average loss: 0.930206, Accuracy: 0.674603
# Train Epoch: 10 [38400/50000 (77%)]	Average loss: 0.928898, Accuracy: 0.674657
#
# Test set: Average loss: 1.0451, Accuracy: 0.620900
#
#
#
# # Best accuracy model(62.86%): cifar10_cnn_model_best_acc_8-epoch.pt

# %% [markdown]
# # 실습과제

# %% [markdown]
# ## Accuracy 74% 이상 성능 달성하기
# - 성능 개선 필수사항: 1) 네트워크 구조 개선 2) 데이터 증대 3) 하이퍼파라미터 수정
# - baseline 모델 Accuracy: 63.67%
# - torchvision: 데이터셋, 데이터증대 함수 제공 (https://pytorch.org/vision/stable/transforms.html)

# %% [markdown]
# 개선 모델 성능: (Accuracy 74% 이상 달성한 성능 작성하기)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 3x32x32 -> 10x32x32
            nn.BatchNorm2d(10),  # 배치 정규화
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 10x32x32 -> 20x32x32
            nn.BatchNorm2d(20),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # 20x32x32 -> 20x16x16 (특징 압축)
            nn.Conv2d(in_channels=20, out_channels=40, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 20x16x16 -> 40x16x16
            nn.BatchNorm2d(40),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=40, out_channels=20, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 20x16x16 -> 40x16x16
            nn.BatchNorm2d(20),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=20, out_channels=40, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 20x16x16 -> 40x16x16
            nn.BatchNorm2d(40),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=40, out_channels=60, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 20x16x16 -> 40x16x16
            nn.BatchNorm2d(60),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=60, out_channels=80, kernel_size=3,
                      stride=1, padding=1, bias=False),  # 40x8x8 -> 80x8x8
            nn.BatchNorm2d(80),
            nn.AdaptiveAvgPool2d(1)  # 80x8x8 -> 80x1x1 (채널 별 평균값 계산)
        )
        self.fc = nn.Linear(80, 10)  # 출력값의 차원은 판별할 클래스 수인 10으로 설정 (CIFAR-10 10종 판별 문제)

    def forward(self, x):
        x = x.float()
        x = x.view(-1, 3, 32, 32)  # view 함수로 tensor 형태 변경: [batch크기, 3, 32, 32]
        x = self.main(x)  # CNN 모델 feed-forward
        x = x.view(-1, 80)  # view 함수로 형태 변경: [batch크기, 80]
        x = self.fc(x)  # 마지막 레이어에는 활성화 함수 사용하지 않음
        return x

print("init model done")
# Out:
# init model done

# %%
batch_size = 64  # 학습 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (학습 과정을 제외하므로 더 큰 배치 사용 가능)
max_epochs = 20  # 학습 데이터셋 총 훈련 횟수
lr = 0.01  # 학습률

# %%
model = Net().to(device)  # 모델 정의
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)  # 최적화 알고리즘 정의 (SGD 사용)
criterion = nn.CrossEntropyLoss()  # 손실 함수 정의 (CrossEntropy 사용)

# %%
best_acc = 0
best_epoch = 0
for epoch in range(1, max_epochs+1):
    train_loss, train_acc = train(log_interval, model, device, train_loader, optimizer, epoch)
    test_loss, test_acc = test(log_interval, model, device, test_loader)

    # 테스트에서 best accuracy 달성하면 모델 저장
    if test_acc > best_acc:
        best_acc = test_acc
        best_epoch = epoch
        torch.save(model, os.path.join(workspace_path, f'cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt'))
        print(f'# save model: cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt\n')

print(f'\n\n# Best accuracy model({best_acc * 100:.2f}%): cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt\n')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Average loss: 2.624154, Accuracy: 0.062500
# Train Epoch: 1 [12800/50000 (26%)]	Average loss: 1.612992, Accuracy: 0.408815
# Train Epoch: 1 [25600/50000 (51%)]	Average loss: 1.471965, Accuracy: 0.464386
# Train Epoch: 1 [38400/50000 (77%)]	Average loss: 1.388374, Accuracy: 0.497296
#
# Test set: Average loss: 1.1968, Accuracy: 0.563200
#
# # save model: cifar10_cnn_model_best_acc_1-epoch.pt
#
# Train Epoch: 2 [0/50000 (0%)]	Average loss: 0.970803, Accuracy: 0.625000
# Train Epoch: 2 [12800/50000 (26%)]	Average loss: 1.053160, Accuracy: 0.625078
# Train Epoch: 2 [25600/50000 (51%)]	Average loss: 1.037411, Accuracy: 0.630455
# Train Epoch: 2 [38400/50000 (77%)]	Average loss: 1.015890, Accuracy: 0.637947
#
# Test set: Average loss: 0.9406, Accuracy: 0.665300
#
# # save model: cifar10_cnn_model_best_acc_2-epoch.pt
#
# Train Epoch: 3 [0/50000 (0%)]	Average loss: 0.797038, Accuracy: 0.734375
# Train Epoch: 3 [12800/50000 (26%)]	Average loss: 0.880217, Accuracy: 0.693952
# Train Epoch: 3 [25600/50000 (51%)]	Average loss: 0.879629, Accuracy: 0.690968
# Train Epoch: 3 [38400/50000 (77%)]	Average loss: 0.875037, Accuracy: 0.692544
#
# Test set: Average loss: 0.8837, Accuracy: 0.687600
#
# # save model: cifar10_cnn_model_best_acc_3-epoch.pt
#
# Train Epoch: 4 [0/50000 (0%)]	Average loss: 0.701403, Accuracy: 0.750000
# Train Epoch: 4 [12800/50000 (26%)]	Average loss: 0.777365, Accuracy: 0.726835
# Train Epoch: 4 [25600/50000 (51%)]	Average loss: 0.786115, Accuracy: 0.724361
# Train Epoch: 4 [38400/50000 (77%)]	Average loss: 0.782212, Accuracy: 0.726575
#
# Test set: Average loss: 0.8628, Accuracy: 0.693200
#
# # save model: cifar10_cnn_model_best_acc_4-epoch.pt
#
# Train Epoch: 5 [0/50000 (0%)]	Average loss: 0.616576, Accuracy: 0.765625
# Train Epoch: 5 [12800/50000 (26%)]	Average loss: 0.691941, Accuracy: 0.756763
# Train Epoch: 5 [25600/50000 (51%)]	Average loss: 0.701563, Accuracy: 0.753507
# Train Epoch: 5 [38400/50000 (77%)]	Average loss: 0.713185, Accuracy: 0.748024
#
# Test set: Average loss: 0.8719, Accuracy: 0.697800
#
# # save model: cifar10_cnn_model_best_acc_5-epoch.pt
#
# Train Epoch: 6 [0/50000 (0%)]	Average loss: 0.772482, Accuracy: 0.718750
# Train Epoch: 6 [12800/50000 (26%)]	Average loss: 0.661600, Accuracy: 0.766169
# Train Epoch: 6 [25600/50000 (51%)]	Average loss: 0.672588, Accuracy: 0.763404
# Train Epoch: 6 [38400/50000 (77%)]	Average loss: 0.675727, Accuracy: 0.761153
#
# Test set: Average loss: 0.8180, Accuracy: 0.711900
#
# # save model: cifar10_cnn_model_best_acc_6-epoch.pt
#
# Train Epoch: 7 [0/50000 (0%)]	Average loss: 0.464028, Accuracy: 0.890625
# Train Epoch: 7 [12800/50000 (26%)]	Average loss: 0.617694, Accuracy: 0.781328
# Train Epoch: 7 [25600/50000 (51%)]	Average loss: 0.633090, Accuracy: 0.777938
# Train Epoch: 7 [38400/50000 (77%)]	Average loss: 0.636549, Accuracy: 0.776310
#
# Test set: Average loss: 0.7834, Accuracy: 0.727800
#
# # save model: cifar10_cnn_model_best_acc_7-epoch.pt
#
# Train Epoch: 8 [0/50000 (0%)]	Average loss: 0.587295, Accuracy: 0.796875
# Train Epoch: 8 [12800/50000 (26%)]	Average loss: 0.583715, Accuracy: 0.794387
# Train Epoch: 8 [25600/50000 (51%)]	Average loss: 0.592851, Accuracy: 0.791108
# Train Epoch: 8 [38400/50000 (77%)]	Average loss: 0.598031, Accuracy: 0.790089
#
# Test set: Average loss: 0.8077, Accuracy: 0.723200
#
# Train Epoch: 9 [0/50000 (0%)]	Average loss: 0.444163, Accuracy: 0.828125
# Train Epoch: 9 [12800/50000 (26%)]	Average loss: 0.572882, Accuracy: 0.799751
# Train Epoch: 9 [25600/50000 (51%)]	Average loss: 0.572295, Accuracy: 0.799369
# Train Epoch: 9 [38400/50000 (77%)]	Average loss: 0.576452, Accuracy: 0.797811
#
# Test set: Average loss: 0.7858, Accuracy: 0.733600
#
# # save model: cifar10_cnn_model_best_acc_9-epoch.pt
#
# Train Epoch: 10 [0/50000 (0%)]	Average loss: 0.574282, Accuracy: 0.812500
# Train Epoch: 10 [12800/50000 (26%)]	Average loss: 0.534080, Accuracy: 0.813666
# Train Epoch: 10 [25600/50000 (51%)]	Average loss: 0.547127, Accuracy: 0.809227
# Train Epoch: 10 [38400/50000 (77%)]	Average loss: 0.550573, Accuracy: 0.805844
#
# Test set: Average loss: 0.7669, Accuracy: 0.741700
#
# # save model: cifar10_cnn_model_best_acc_10-epoch.pt
#
# Train Epoch: 11 [0/50000 (0%)]	Average loss: 0.470045, Accuracy: 0.890625
# Train Epoch: 11 [12800/50000 (26%)]	Average loss: 0.515698, Accuracy: 0.817397
# Train Epoch: 11 [25600/50000 (51%)]	Average loss: 0.516179, Accuracy: 0.817565
# Train Epoch: 11 [38400/50000 (77%)]	Average loss: 0.523688, Accuracy: 0.815282
#
# Test set: Average loss: 0.7969, Accuracy: 0.730600
#
# Train Epoch: 12 [0/50000 (0%)]	Average loss: 0.493956, Accuracy: 0.796875
# Train Epoch: 12 [12800/50000 (26%)]	Average loss: 0.489781, Accuracy: 0.830846
# Train Epoch: 12 [25600/50000 (51%)]	Average loss: 0.495394, Accuracy: 0.827112
# Train Epoch: 12 [38400/50000 (77%)]	Average loss: 0.501246, Accuracy: 0.824563
#
# Test set: Average loss: 0.7934, Accuracy: 0.737500
#
# Train Epoch: 13 [0/50000 (0%)]	Average loss: 0.443021, Accuracy: 0.859375
# Train Epoch: 13 [12800/50000 (26%)]	Average loss: 0.472239, Accuracy: 0.832556
# Train Epoch: 13 [25600/50000 (51%)]	Average loss: 0.474992, Accuracy: 0.831749
# Train Epoch: 13 [38400/50000 (77%)]	Average loss: 0.482221, Accuracy: 0.827709
#
# Test set: Average loss: 0.7681, Accuracy: 0.750900
#
# # save model: cifar10_cnn_model_best_acc_13-epoch.pt
#
# Train Epoch: 14 [0/50000 (0%)]	Average loss: 0.416964, Accuracy: 0.828125
# Train Epoch: 14 [12800/50000 (26%)]	Average loss: 0.446975, Accuracy: 0.844838
# Train Epoch: 14 [25600/50000 (51%)]	Average loss: 0.458963, Accuracy: 0.839425
# Train Epoch: 14 [38400/50000 (77%)]	Average loss: 0.464197, Accuracy: 0.836886
#
# Test set: Average loss: 0.7831, Accuracy: 0.737600
#
# Train Epoch: 15 [0/50000 (0%)]	Average loss: 0.434555, Accuracy: 0.828125
# Train Epoch: 15 [12800/50000 (26%)]	Average loss: 0.433287, Accuracy: 0.848881
# Train Epoch: 15 [25600/50000 (51%)]	Average loss: 0.444767, Accuracy: 0.844140
# Train Epoch: 15 [38400/50000 (77%)]	Average loss: 0.447891, Accuracy: 0.843204
#
# Test set: Average loss: 0.8867, Accuracy: 0.718300
#
# Train Epoch: 16 [0/50000 (0%)]	Average loss: 0.200816, Accuracy: 0.921875
# Train Epoch: 16 [12800/50000 (26%)]	Average loss: 0.408506, Accuracy: 0.857587
# Train Epoch: 16 [25600/50000 (51%)]	Average loss: 0.417307, Accuracy: 0.852907
# Train Epoch: 16 [38400/50000 (77%)]	Average loss: 0.427443, Accuracy: 0.849574
#
# Test set: Average loss: 0.8067, Accuracy: 0.733200
#
# Train Epoch: 17 [0/50000 (0%)]	Average loss: 0.360018, Accuracy: 0.828125
# Train Epoch: 17 [12800/50000 (26%)]	Average loss: 0.402091, Accuracy: 0.858053
# Train Epoch: 17 [25600/50000 (51%)]	Average loss: 0.400173, Accuracy: 0.858050
# Train Epoch: 17 [38400/50000 (77%)]	Average loss: 0.413984, Accuracy: 0.853005
#
# Test set: Average loss: 0.8768, Accuracy: 0.729900
#
# Train Epoch: 18 [0/50000 (0%)]	Average loss: 0.399513, Accuracy: 0.843750
# Train Epoch: 18 [12800/50000 (26%)]	Average loss: 0.380394, Accuracy: 0.865205
# Train Epoch: 18 [25600/50000 (51%)]	Average loss: 0.388793, Accuracy: 0.861323
# Train Epoch: 18 [38400/50000 (77%)]	Average loss: 0.403117, Accuracy: 0.856307
#
# Test set: Average loss: 0.8714, Accuracy: 0.729900
#
# Train Epoch: 19 [0/50000 (0%)]	Average loss: 0.304185, Accuracy: 0.906250
# Train Epoch: 19 [12800/50000 (26%)]	Average loss: 0.367443, Accuracy: 0.867615
# Train Epoch: 19 [25600/50000 (51%)]	Average loss: 0.379878, Accuracy: 0.863388
# Train Epoch: 19 [38400/50000 (77%)]	Average loss: 0.388186, Accuracy: 0.860909
#
# Test set: Average loss: 0.8172, Accuracy: 0.741200
#
# Train Epoch: 20 [0/50000 (0%)]	Average loss: 0.478007, Accuracy: 0.875000
# Train Epoch: 20 [12800/50000 (26%)]	Average loss: 0.363409, Accuracy: 0.870802
# Train Epoch: 20 [25600/50000 (51%)]	Average loss: 0.375535, Accuracy: 0.867363
# Train Epoch: 20 [38400/50000 (77%)]	Average loss: 0.382009, Accuracy: 0.864367
#
# Test set: Average loss: 0.8563, Accuracy: 0.736600
#
#
#
# # Best accuracy model(75.09%): cifar10_cnn_model_best_acc_13-epoch.pt

# %% [markdown]
# Conv-BN-ReLU 레이어 3개 추가하기, epoch 20
